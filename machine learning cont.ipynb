# %%
import pandas as pd

# %%
housing=pd.read_csv("data.csv")

# %%
housing
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
# first
#check for empty spaces in the dataset 
# it is called data pre-processin or data wrangling
housing.isna().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
# this df.correlation()[] helps to check the value is closest to accurate and the closer to "1" 
#the more the accurate the column to be used
housing.corr()["price"]
# Out:
# price            1.000000
# bedrooms         0.200336
# bathrooms        0.327110
# sqft_living      0.430410
# sqft_lot         0.050451
# floors           0.151461
# waterfront       0.135648
# view             0.228504
# condition        0.034915
# sqft_above       0.367570
# sqft_basement    0.210427
# yr_built         0.021857
# yr_renovated    -0.028774
# Name: price, dtype: float64

# %%
# extract your dependent and independent
#y= dependent/target (house price)
#x= variables, factors
#using [0:1] means just 1 column


y=housing.iloc[0:,1]
X=housing.iloc[0:,2:14]

# %%
from sklearn.linear_model import LinearRegression

# %%
X
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0          3.0       1.50         1340      7912     1.5           0     0
# 1          5.0       2.50         3650      9050     2.0           0     4
# 2          3.0       2.00         1930     11947     1.0           0     0
# 3          3.0       2.25         2000      8030     1.0           0     0
# 4          4.0       2.50         1940     10500     1.0           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 4595       3.0       1.75         1510      6360     1.0           0     0
# 4596       3.0       2.50         1460      7573     2.0           0     0
# 4597       3.0       2.50         3010      7014     2.0           0     0
# 4598       4.0       2.00         2090      6630     1.0           0     0
# 4599       3.0       2.50         1490      8102     2.0           0     0
#
#       condition  sqft_above  sqft_basement  yr_built  yr_renovated
# ...

# %% [markdown]
# # SPLIT X AND Y

# %%
from sklearn.model_selection import train_test_split

# %%
# the x and y are variables and can be changed
X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.75, random_state=0)

# %%
# this is to import the modelling for the modelling

from sklearn import linear_model
#from sklearn.model_selection import LinearRegression

# %%
X_train_prediction=LinearRegression().fit(X_train,y_train).predict(X_train).round()

# %%
X_train_prediction
# Out:
# array([305325., 750405., 868450., ..., 425396., 974149., 359529.])

# %%
seventy=pd.DataFrame(X_train)

# %%
seventy["Prediction"]=X_train_prediction

# %%
X_train
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 747        3.0       1.75         1680    250470     1.0           0     0
# 1312       3.0       3.00         2980     28000     1.0           0     0
# 4265       4.0       3.50         3360      9767     2.0           0     0
# 1031       3.0       2.00         2010    251341     2.0           0     0
# 1004       3.0       2.50         2480      9041     2.0           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 1033       3.0       1.50         1270      1443     3.0           0     0
# 3264       2.0       1.00          970      5500     1.0           0     0
# 1653       5.0       2.75         2080     13189     2.0           0     0
# 2607       4.0       2.50         3070     34412     1.0           0     3
# 2732       3.0       1.75         1700      8432     1.0           0     0
#
# ...

# %%
X_test_prediction=LinearRegression().fit(X_test,y_test).predict(X_test).round()

# %%
thirty=pd.DataFrame(X_test)

# %%
#THE NAME ON X_TEST MUST BE SAME ON X_TRAIN FOR IT TO APPEAR ON THE SAME COLUMN

thirty["Prediction"]=X_test_prediction

# %%
thirty
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 991        3.0       2.50         2090      4700     2.0           0     0
# 2824       4.0       2.50         2640      8625     2.0           0     0
# 1906       1.0       1.00          650     15364     1.0           0     0
# 1471       4.0       2.00         2510     38141     1.0           0     0
# 1813       4.0       3.50         2790     10125     1.5           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 212        5.0       2.75         1800      3780     1.5           0     0
# 3919       3.0       1.50         1380      4500     1.0           0     0
# 1064       3.0       2.75         2100     10362     2.0           0     0
# 3293       5.0       2.50         2980      5377     2.0           0     0
# 75         2.0       3.00         1270      1175     2.0           0     0
#
# ...

# %%
concatenated=pd.concat([seventy,thirty],axis=0,ignore_index=True)

# %%
concatenated.fillna(0)
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0          3.0       1.75         1680    250470     1.0           0     0
# 1          3.0       3.00         2980     28000     1.0           0     0
# 2          4.0       3.50         3360      9767     2.0           0     0
# 3          3.0       2.00         2010    251341     2.0           0     0
# 4          3.0       2.50         2480      9041     2.0           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 4595       5.0       2.75         1800      3780     1.5           0     0
# 4596       3.0       1.50         1380      4500     1.0           0     0
# 4597       3.0       2.75         2100     10362     2.0           0     0
# 4598       5.0       2.50         2980      5377     2.0           0     0
# 4599       2.0       3.00         1270      1175     2.0           0     0
#
# ...
