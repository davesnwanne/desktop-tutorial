# %%
#specifying the delimiter is used to seprate columns attached together
import pandas as pd
messy=pd.read_csv("messy_data.csv", delimiter=";")
messy
# Out:
#     IMBD title ID              Original titl�  Release year  \
# 0       tt0111161    The Shawshank Redemption    1995-02-10
# 1       tt0068646               The Godfather    09 21 1972
# 2       tt0468569             The Dark Knight   23 -07-2008
# 3       tt0071562      The Godfather: Part II    1975-09-25
# 4       tt0110912                Pulp Fiction    1994-10-28
# ..            ...                         ...           ...
# 96      tt0070735                   The Sting    1974-03-21
# 97      tt0082096                    Das Boot    1982-03-18
# 98      tt0059578  Per qualche dollaro in più    1965-12-20
# 99      tt1832382     Jodaeiye Nader az Simin    2011-10-21
# 100     tt0045152         Singin' in the Rain    1953-02-05
#
#                           Genr� Duration       Country Content Rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
#use open to check the encoding of the file while you have an uincode error
open("messy_data.csv")

#use the delimeter to specify what is seperating the columns in the columns header 
# delimiter=";" eg
# Out:
# <_io.TextIOWrapper name='messy_data.csv' mode='r' encoding='cp1252'>

# %%
del messy["Unnamed: 8"]

# %%
#remove characters that are not numbers
messy["Score,,,,"].str.replace("\W","", regex=True)
messy["Score,,,,"]=messy["Score,,,,"].str.replace("\W","", regex=True)
messy
# Out:
#     IMBD title ID              Original titl�  Release year  \
# 0       tt0111161    The Shawshank Redemption    1995-02-10
# 1       tt0068646               The Godfather    09 21 1972
# 2       tt0468569             The Dark Knight   23 -07-2008
# 3       tt0071562      The Godfather: Part II    1975-09-25
# 4       tt0110912                Pulp Fiction    1994-10-28
# ..            ...                         ...           ...
# 96      tt0070735                   The Sting    1974-03-21
# 97      tt0082096                    Das Boot    1982-03-18
# 98      tt0059578  Per qualche dollaro in più    1965-12-20
# 99      tt1832382     Jodaeiye Nader az Simin    2011-10-21
# 100     tt0045152         Singin' in the Rain    1953-02-05
#
#                           Genr� Duration       Country Content Rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
#to replace certain rows in a column in a dataframe
messy["Score,,,,"].str.replace("89f","89")
messy["Score,,,,"]=messy["Score,,,,"].str.replace("89f","89")

# %%
messy
# Out:
#     IMBD title ID              Original titl�  Release year  \
# 0       tt0111161    The Shawshank Redemption    1995-02-10
# 1       tt0068646               The Godfather    09 21 1972
# 2       tt0468569             The Dark Knight   23 -07-2008
# 3       tt0071562      The Godfather: Part II    1975-09-25
# 4       tt0110912                Pulp Fiction    1994-10-28
# ..            ...                         ...           ...
# 96      tt0070735                   The Sting    1974-03-21
# 97      tt0082096                    Das Boot    1982-03-18
# 98      tt0059578  Per qualche dollaro in più    1965-12-20
# 99      tt1832382     Jodaeiye Nader az Simin    2011-10-21
# 100     tt0045152         Singin' in the Rain    1953-02-05
#
#                           Genr� Duration       Country Content Rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
messy=messy.fillna(0)

# %%
#renaming columns in a dataframe because rename is a regular expression use {} dictionary 
messy.rename(columns={"Score,,,,":"score"})
messy=messy.rename(columns={"Score,,,,":"score"})

# %%
messy=messy.rename(columns={"Original titl�":"Original title","Genr�":"Genre"})

# %%
pd.set_option("display.max_colwidth",None)

# %%
messy
# Out:
#     IMBD title ID              Original title  Release year  \
# 0       tt0111161    The Shawshank Redemption    1995-02-10
# 1       tt0068646               The Godfather    09 21 1972
# 2       tt0468569             The Dark Knight   23 -07-2008
# 3       tt0071562      The Godfather: Part II    1975-09-25
# 4       tt0110912                Pulp Fiction    1994-10-28
# ..            ...                         ...           ...
# 96      tt0070735                   The Sting    1974-03-21
# 97      tt0082096                    Das Boot    1982-03-18
# 98      tt0059578  Per qualche dollaro in più    1965-12-20
# 99      tt1832382     Jodaeiye Nader az Simin    2011-10-21
# 100     tt0045152         Singin' in the Rain    1953-02-05
#
#                           Genre Duration       Country Content Rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
messy["IMBD title ID"]=messy["IMBD title ID"].str.replace("tt","",regex=True)

# %%
messy
# Out:
#     IMBD title ID  \
# 0         0111161
# 1         0068646
# 2         0468569
# 3         0071562
# 4         0110912
# 5         0167260
# 6         0108052
# 7         0050083
# 8         1375666
# 9         0137523
# 10        0109830
# 11        0120737
# 12        0060196
# 13            NaN
# 14        0133093
# 15        0167261
# 16        0080684
# 17        0099685
# 18        0073486
# 19        0816692
# 20        0114369
# 21        0102926
# 22        0076759
# 23        0120815
# 24        0120689
# 25        0317248
# 26        0245429
# 27        0118799
# 28        6751668
# 29        0038650
# 30        0047478
# 31        0172495
# 32        0407887
# 33        0482571
# 34        0088763
# 35        0120586
# 36        0110413
# 37        0103064
# 38        0114814
# 39        0110357
# 40        7286456
# 41        1675434
# 42        0253474
# 43        2582802
# 44        0054215
# 45        0034583
# 46        0064116
# 47        0095327
# ...

# %%
#to replace or remove errors(characters that is not number or strings) in the columns in a dataframe
messy.columns.str.replace("\W", "", regex=True)

messy.columns=messy.columns.str.replace("\W", "", regex=True)

# %%
# it is used to remove spaces before or after a string in the dataframe
messy.columns.str.strip()
# Out:
# Index(['IMBDtitleID', 'Originaltitle', 'Releaseyear', 'Genre', 'Duration',
#        'Country', 'ContentRating', 'Director', 'Income', 'Votes', 'score'],
#       dtype='object')

# %%
# this is used to check the columns and rows if there are objects or strings
messy.columns.str.isalpha()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %% [markdown]
# # when you call out a particular column and it shows errors its most likely because of the spaces in it
# #  so you have to strip the columns of the spaces using this function called .strip()

# %%
messy["Votes"]
# Out:
# 0      2.278.845
# 1      1.572.674
# 2      2.241.615
# 3      1.098.714
# 4      1.780.147
# 5      1.604.280
# 6      1.183.248
# 7        668.473
# 8      2.002.816
# 9      1.807.440
# 10     1.755.490
# 11     1.619.920
# 12       672.499
# 13             0
# 14     1.632.315
# 15     1.449.778
# 16     1.132.073
# 17       991.505
# 18       891.071
# 19     1.449.256
# 20     1.402.015
# 21     1.234.134
# 22     1.204.107
# 23     1.203.825
# 24     1.112.336
# 25       685.856
# 26       626.693
# 27       605.648
# 28       470.931
# 29       388.310
# 30       307.958
# 31     1.308.193
# 32     1.159.703
# 33     1.155.723
# 34     1.027.330
# 35     1.014.218
# 36     1.007.598
# 37       974.970
# 38       968.947
# 39       917.248
# 40       855.097
# 41       736.691
# 42       707.942
# 43       690.732
# 44       586.765
# 45       509.953
# 46       295.220
# 47       225.438
# 48       223.050
# 49       211.250
# 50     1.480.582
# 51     1.317.856
# ...

# %%
for m in messy.columns:
    messy[m]=messy[m].str.strip()
    
# used to remove extra spaces in the whole dataframe

# %%
messy
# Out:
#     IMBDtitleID  \
# 0       0111161
# 1       0068646
# 2       0468569
# 3       0071562
# 4       0110912
# 5       0167260
# 6       0108052
# 7       0050083
# 8       1375666
# 9       0137523
# 10      0109830
# 11      0120737
# 12      0060196
# 13          NaN
# 14      0133093
# 15      0167261
# 16      0080684
# 17      0099685
# 18      0073486
# 19      0816692
# 20      0114369
# 21      0102926
# 22      0076759
# 23      0120815
# 24      0120689
# 25      0317248
# 26      0245429
# 27      0118799
# 28      6751668
# 29      0038650
# 30      0047478
# 31      0172495
# 32      0407887
# 33      0482571
# 34      0088763
# 35      0120586
# 36      0110413
# 37      0103064
# 38      0114814
# 39      0110357
# 40      7286456
# 41      1675434
# 42      0253474
# 43      2582802
# 44      0054215
# 45      0034583
# 46      0064116
# 47      0095327
# 48      0095765
# 49      0027977
# 50      1345836
# 51      1853728
# 52      0209144
# 53      0910970
# ...

# %%
messy["Income"].str.replace(",","")
messy["Income"]=messy["Income"].str.replace("\W","",regex=True)
messy
# Out:
#     IMBDtitleID  \
# 0       0111161
# 1       0068646
# 2       0468569
# 3       0071562
# 4       0110912
# 5       0167260
# 6       0108052
# 7       0050083
# 8       1375666
# 9       0137523
# 10      0109830
# 11      0120737
# 12      0060196
# 13          NaN
# 14      0133093
# 15      0167261
# 16      0080684
# 17      0099685
# 18      0073486
# 19      0816692
# 20      0114369
# 21      0102926
# 22      0076759
# 23      0120815
# 24      0120689
# 25      0317248
# 26      0245429
# 27      0118799
# 28      6751668
# 29      0038650
# 30      0047478
# 31      0172495
# 32      0407887
# 33      0482571
# 34      0088763
# 35      0120586
# 36      0110413
# 37      0103064
# 38      0114814
# 39      0110357
# 40      7286456
# 41      1675434
# 42      0253474
# 43      2582802
# 44      0054215
# 45      0034583
# 46      0064116
# 47      0095327
# 48      0095765
# 49      0027977
# 50      1345836
# 51      1853728
# 52      0209144
# 53      0910970
# ...

# %%
# to replace a column name in a dataframe you use rename and column and use inplace=true
messy.rename(columns={"Score,,,":"Score"},inplace=True)

# %%
#to use locate where you have an error you use iloc
#[16 is the column number, while -1 0r 12 is the column number]
messy.iloc[16, -1] = 87

# %%
messy
# Out:
#     IMBDtitleID  \
# 0       0111161
# 1       0068646
# 2       0468569
# 3       0071562
# 4       0110912
# 5       0167260
# 6       0108052
# 7       0050083
# 8       1375666
# 9       0137523
# 10      0109830
# 11      0120737
# 12      0060196
# 13            0
# 14      0133093
# 15      0167261
# 16      0080684
# 17      0099685
# 18      0073486
# 19      0816692
# 20      0114369
# 21      0102926
# 22      0076759
# 23      0120815
# 24      0120689
# 25      0317248
# 26      0245429
# 27      0118799
# 28      6751668
# 29      0038650
# 30      0047478
# 31      0172495
# 32      0407887
# 33      0482571
# 34      0088763
# 35      0120586
# 36      0110413
# 37      0103064
# 38      0114814
# 39      0110357
# 40      7286456
# 41      1675434
# 42      0253474
# 43      2582802
# 44      0054215
# 45      0034583
# 46      0064116
# 47      0095327
# 48      0095765
# 49      0027977
# 50      1345836
# 51      1853728
# 52      0209144
# 53      0910970
# ...

# %%
#using iloc locate the position and then change it
messy.iloc[6,4]=0
messy
# Out:
#     IMBDtitleID  \
# 0       0111161
# 1       0068646
# 2       0468569
# 3       0071562
# 4       0110912
# 5       0167260
# 6       0108052
# 7       0050083
# 8       1375666
# 9       0137523
# 10      0109830
# 11      0120737
# 12      0060196
# 13            0
# 14      0133093
# 15      0167261
# 16      0080684
# 17      0099685
# 18      0073486
# 19      0816692
# 20      0114369
# 21      0102926
# 22      0076759
# 23      0120815
# 24      0120689
# 25      0317248
# 26      0245429
# 27      0118799
# 28      6751668
# 29      0038650
# 30      0047478
# 31      0172495
# 32      0407887
# 33      0482571
# 34      0088763
# 35      0120586
# 36      0110413
# 37      0103064
# 38      0114814
# 39      0110357
# 40      7286456
# 41      1675434
# 42      0253474
# 43      2582802
# 44      0054215
# 45      0034583
# 46      0064116
# 47      0095327
# 48      0095765
# 49      0027977
# 50      1345836
# 51      1853728
# 52      0209144
# 53      0910970
# ...

# %%
messy=messy.fillna(0)

# %%
#you use this formular to remove an error i.e dataframe.iloc[row number, column number]=the error to be changed
messy.iloc[3,-3]=40835783
