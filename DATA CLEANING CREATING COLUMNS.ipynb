# %%
import pandas as pd

# %%
covida=pd.read_csv("covid_19_data2.csv")

# %%
covida
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1       1/22/2020              Anhui  Mainland China
# 1            2       1/22/2020            Beijing  Mainland China
# 2            3       1/22/2020          Chongqing  Mainland China
# 3            4       1/22/2020             Fujian  Mainland China
# 4            5       1/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425       5/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426       5/29/2021            Zeeland     Netherlands
# 306426  306427       5/29/2021           Zhejiang  Mainland China
# 306427  306428       5/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429       5/29/2021       Zuid-Holland     Netherlands
#
#             Last Update  Confirmed  Deaths  Recovered totalconfirmed
# 0       1/22/2020 17:00          1       0          0
# ...

# %%
covida.isna()
# Out:
#           SNo  ObservationDate  Province/State  Country/Region  Last Update  \
# 0       False            False           False           False        False
# 1       False            False           False           False        False
# 2       False            False           False           False        False
# 3       False            False           False           False        False
# 4       False            False           False           False        False
# ...       ...              ...             ...             ...          ...
# 306424  False            False           False           False        False
# 306425  False            False           False           False        False
# 306426  False            False           False           False        False
# 306427  False            False           False           False        False
# 306428  False            False           False           False        False
#
#         Confirmed  Deaths  Recovered
# ...

# %%
covida.dtypes
# Out:
# SNo                 int64
# ObservationDate    object
# Province/State     object
# Country/Region     object
# Last Update        object
# Confirmed           int64
# Deaths              int64
# Recovered           int64
# dtype: object

# %%
covida.columns
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
covida[["Province/State","Country/Region","ObservationDate"]]
# Out:
#            Province/State  Country/Region ObservationDate
# 0                   Anhui  Mainland China       1/22/2020
# 1                 Beijing  Mainland China       1/22/2020
# 2               Chongqing  Mainland China       1/22/2020
# 3                  Fujian  Mainland China       1/22/2020
# 4                   Gansu  Mainland China       1/22/2020
# ...                   ...             ...             ...
# 306424  Zaporizhia Oblast         Ukraine       5/29/2021
# 306425            Zeeland     Netherlands       5/29/2021
# 306426           Zhejiang  Mainland China       5/29/2021
# 306427    Zhytomyr Oblast         Ukraine       5/29/2021
# 306428       Zuid-Holland     Netherlands       5/29/2021
#
# [306429 rows x 3 columns]

# %%
covida.isna()
# Out:
#           SNo  ObservationDate  Province/State  Country/Region  Last Update  \
# 0       False            False           False           False        False
# 1       False            False           False           False        False
# 2       False            False           False           False        False
# 3       False            False           False           False        False
# 4       False            False           False           False        False
# ...       ...              ...             ...             ...          ...
# 306424  False            False           False           False        False
# 306425  False            False           False           False        False
# 306426  False            False           False           False        False
# 306427  False            False           False           False        False
# 306428  False            False           False           False        False
#
#         Confirmed  Deaths  Recovered
# ...

# %%
covidafill=covida.fillna(0)

# %%
covida["totalconfirmed"]=""

# %%
covida.loc[covida["Confirmed"]==0]
# Out:
#            SNo ObservationDate  Province/State  Country/Region  \
# 4            5       1/22/2020           Gansu  Mainland China
# 10          11       1/22/2020    Heilongjiang  Mainland China
# 12          13       1/22/2020       Hong Kong       Hong Kong
# 15          16       1/22/2020  Inner Mongolia  Mainland China
# 18          19       1/22/2020           Jilin  Mainland China
# ...        ...             ...             ...             ...
# 306368  306369       5/29/2021         Unknown  Mainland China
# 306369  306370       5/29/2021         Unknown          Mexico
# 306371  306372       5/29/2021         Unknown            Peru
# 306372  306373       5/29/2021         Unknown           Spain
# 306373  306374       5/29/2021         Unknown              UK
#
#             Last Update  Confirmed  Deaths  Recovered totalconfirmed
# 4       1/22/2020 17:00          0       0          0
# 10      1/22/2020 17:00          0       0          0
# ...

# %%
covida["Confirmed"].sum()
# Out:
# 26252051758

# %%
covida["Confirmed"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0              1
# 1             14
# 2              6
# 3              1
# 4              0
#            ...
# 306424    102641
# 306425     29147
# 306426      1364
# 306427     87550
# 306428    391559
# Name: Confirmed, Length: 306429, dtype: int64>

# %%
covida["Deaths"].sum()
# Out:
# 624013017

# %%
covida["Recovered"].sum()
# Out:
# 15450237912

# %%
covida.loc[covida["Country/Region"]=="Mainland China"]
# Out:
#            SNo ObservationDate Province/State  Country/Region  \
# 0            1       1/22/2020          Anhui  Mainland China
# 1            2       1/22/2020        Beijing  Mainland China
# 2            3       1/22/2020      Chongqing  Mainland China
# 3            4       1/22/2020         Fujian  Mainland China
# 4            5       1/22/2020          Gansu  Mainland China
# ...        ...             ...            ...             ...
# 306340  306341       5/29/2021          Tibet  Mainland China
# 306368  306369       5/29/2021        Unknown  Mainland China
# 306412  306413       5/29/2021       Xinjiang  Mainland China
# 306420  306421       5/29/2021         Yunnan  Mainland China
# 306426  306427       5/29/2021       Zhejiang  Mainland China
#
#             Last Update  Confirmed  Deaths  Recovered totalconfirmed
# 0       1/22/2020 17:00          1       0          0
# 1       1/22/2020 17:00         14       0          0
# ...
