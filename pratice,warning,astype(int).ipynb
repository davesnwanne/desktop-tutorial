# %%
import pandas as pd
pd.read_excel("date function exercise.xlsx")
# Out:
#    Unnamed: 0                                         Unnamed: 1  \
# 0         NaN                                         Exercise 4
# 1         NaN                                                NaN
# 2         NaN  We have a data of 500 different orders from an...
# 3         NaN                                                NaN
# 4         NaN                                                  1
# 5         NaN                                                  2
# 6         NaN                                                  3
# 7         NaN                                                  4
#
#                                           Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                                                NaN         NaN         NaN
# 1                                                NaN         NaN         NaN
# 2                                                NaN         NaN         NaN
# ...

# %% [markdown]
# # To remove warnings from the page

# %%
import warnings
warnings.filterwarnings("ignore")
#this is to remove the warnings

# %%
exercise=pd.read_excel("date function exercise.xlsx",sheet_name="Practice",header=[2])
# using a row as header use header= the specified row number

# %%
exercise
# Out:
#      Unnamed: 0  Row ID        Order ID Order Date  Ship Date Customer ID  \
# 0           NaN       1  CA-2016-152156 2016-11-08 2016-11-11    CG-12520
# 1           NaN       2  CA-2016-152156 2016-11-08 2016-11-11    CG-12520
# 2           NaN       3  CA-2016-138688 2016-06-12 2016-06-16    DV-13045
# 3           NaN       4  US-2015-108966 2015-10-11 2015-10-18    SO-20335
# 4           NaN       5  US-2015-108966 2015-10-11 2015-10-18    SO-20335
# ..          ...     ...             ...        ...        ...         ...
# 495         NaN     496  CA-2015-134782 2015-12-27 2015-12-31    MD-17350
# 496         NaN     497  CA-2016-126158 2016-07-25 2016-07-31    SC-20095
# 497         NaN     498  CA-2016-126158 2016-07-25 2016-07-31    SC-20095
# 498         NaN     499  CA-2016-126158 2016-07-25 2016-07-31    SC-20095
# 499         NaN     500  CA-2016-126158 2016-07-25 2016-07-31    SC-20095
#
#           Product ID     Sales  Order Month  Ship Time  Unnamed: 10  \
# ...

# %%
exercise.dtypes
# Out:
# Unnamed: 0                        float64
# Row ID                              int64
# Order ID                           object
# Order Date                 datetime64[ns]
# Ship Date                  datetime64[ns]
# Customer ID                        object
# Product ID                         object
# Sales                             float64
# Order Month                       float64
# Ship Time                         float64
# Unnamed: 10                       float64
# Order Count                        object
# Unnamed: 12                        object
# Unnamed: 13                       float64
# Average Processing time            object
# Unnamed: 15                       float64
# dtype: object

# %%
exercise[["Row ID", "Order ID","Order Date","Ship Date","Customer ID","Product ID","Sales"]]
newwork=exercise[["Row ID","Order ID","Order Date","Ship Date","Customer ID","Product ID","Sales"]]

# %%
#extracting specificied rows
newwork
# Out:
#      Row ID        Order ID Order Date  Ship Date Customer ID  \
# 0         1  CA-2016-152156 2016-11-08 2016-11-11    CG-12520
# 1         2  CA-2016-152156 2016-11-08 2016-11-11    CG-12520
# 2         3  CA-2016-138688 2016-06-12 2016-06-16    DV-13045
# 3         4  US-2015-108966 2015-10-11 2015-10-18    SO-20335
# 4         5  US-2015-108966 2015-10-11 2015-10-18    SO-20335
# ..      ...             ...        ...        ...         ...
# 495     496  CA-2015-134782 2015-12-27 2015-12-31    MD-17350
# 496     497  CA-2016-126158 2016-07-25 2016-07-31    SC-20095
# 497     498  CA-2016-126158 2016-07-25 2016-07-31    SC-20095
# 498     499  CA-2016-126158 2016-07-25 2016-07-31    SC-20095
# 499     500  CA-2016-126158 2016-07-25 2016-07-31    SC-20095
#
#           Product ID     Sales
# 0    FUR-BO-10001798  261.9600
# 1    FUR-CH-10000454  731.9400
# 2    OFF-LA-10000240   14.6200
# 3    FUR-TA-10000577  957.5775
# 4    OFF-ST-10000760   22.3680
# ...

# %%
#create a column "order month" to find out the month of the order date
newwork["Order Date"]
# Out:
# 0     2016-11-08
# 1     2016-11-08
# 2     2016-06-12
# 3     2015-10-11
# 4     2015-10-11
#          ...
# 495   2015-12-27
# 496   2016-07-25
# 497   2016-07-25
# 498   2016-07-25
# 499   2016-07-25
# Name: Order Date, Length: 500, dtype: datetime64[ns]

# %%
newwork["Order Date"].dt.to_period("M")
# Out:
# 0      2016-11
# 1      2016-11
# 2      2016-06
# 3      2015-10
# 4      2015-10
#         ...
# 495    2015-12
# 496    2016-07
# 497    2016-07
# 498    2016-07
# 499    2016-07
# Name: Order Date, Length: 500, dtype: period[M]

# %%
newwork["ordermonth"]=newwork["Order Date"].dt.to_period("M")

# %%
newwork
# Out:
#      Row ID        Order ID Order Date  Ship Date Customer ID  \
# 0         1  CA-2016-152156 2016-11-08 2016-11-11    CG-12520
# 1         2  CA-2016-152156 2016-11-08 2016-11-11    CG-12520
# 2         3  CA-2016-138688 2016-06-12 2016-06-16    DV-13045
# 3         4  US-2015-108966 2015-10-11 2015-10-18    SO-20335
# 4         5  US-2015-108966 2015-10-11 2015-10-18    SO-20335
# ..      ...             ...        ...        ...         ...
# 495     496  CA-2015-134782 2015-12-27 2015-12-31    MD-17350
# 496     497  CA-2016-126158 2016-07-25 2016-07-31    SC-20095
# 497     498  CA-2016-126158 2016-07-25 2016-07-31    SC-20095
# 498     499  CA-2016-126158 2016-07-25 2016-07-31    SC-20095
# 499     500  CA-2016-126158 2016-07-25 2016-07-31    SC-20095
#
#           Product ID     Sales ordermonth
# 0    FUR-BO-10001798  261.9600    2016-11
# 1    FUR-CH-10000454  731.9400    2016-11
# 2    OFF-LA-10000240   14.6200    2016-06
# 3    FUR-TA-10000577  957.5775    2015-10
# ...

# %%
del newwork["ordermonths"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ordermonths'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-953cd83cd43e> in <module>
# ----> 1 del newwork["ordermonths"]
# ...

# %%
del newwork["order_month"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'order_month'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-535a33d87d6b> in <module>
# ----> 1 del newwork["order_month"]
# ...

# %%
newwork
# Out:
#      Row ID        Order ID Order Date  Ship Date Customer ID  \
# 0         1  CA-2016-152156 2016-11-08 2016-11-11    CG-12520
# 1         2  CA-2016-152156 2016-11-08 2016-11-11    CG-12520
# 2         3  CA-2016-138688 2016-06-12 2016-06-16    DV-13045
# 3         4  US-2015-108966 2015-10-11 2015-10-18    SO-20335
# 4         5  US-2015-108966 2015-10-11 2015-10-18    SO-20335
# ..      ...             ...        ...        ...         ...
# 495     496  CA-2015-134782 2015-12-27 2015-12-31    MD-17350
# 496     497  CA-2016-126158 2016-07-25 2016-07-31    SC-20095
# 497     498  CA-2016-126158 2016-07-25 2016-07-31    SC-20095
# 498     499  CA-2016-126158 2016-07-25 2016-07-31    SC-20095
# 499     500  CA-2016-126158 2016-07-25 2016-07-31    SC-20095
#
#           Product ID     Sales ordermonth
# 0    FUR-BO-10001798  261.9600    2016-11
# 1    FUR-CH-10000454  731.9400    2016-11
# 2    OFF-LA-10000240   14.6200    2016-06
# 3    FUR-TA-10000577  957.5775    2015-10
# ...

# %%
#  to print months in string convert to string ,using st.split()
newwork["Order Date"].astype(str)
# Out:
# 0      2016-11-08
# 1      2016-11-08
# 2      2016-06-12
# 3      2015-10-11
# 4      2015-10-11
#           ...
# 495    2015-12-27
# 496    2016-07-25
# 497    2016-07-25
# 498    2016-07-25
# 499    2016-07-25
# Name: Order Date, Length: 500, dtype: object

# %%
newwork["Order Date"]=newwork["Order Date"].astype(str)

# %%
dd=newwork["Order Date"].str.split("-",expand=True)
# this will split the date into different bits from each delimiter

# %%
dd
# Out:
#         0   1   2
# 0    2016  11  08
# 1    2016  11  08
# 2    2016  06  12
# 3    2015  10  11
# 4    2015  10  11
# ..    ...  ..  ..
# 495  2015  12  27
# 496  2016  07  25
# 497  2016  07  25
# 498  2016  07  25
# 499  2016  07  25
#
# [500 rows x 3 columns]

# %%
dd[1]
#this will select the first column in the dd database
# Out:
# 0      11
# 1      11
# 2      06
# 3      10
# 4      10
#        ..
# 495    12
# 496    07
# 497    07
# 498    07
# 499    07
# Name: 1, Length: 500, dtype: object

# %%
newwork["ordermonth"]=dd[1]

# %%
newwork
# Out:
#      Row ID        Order ID  Order Date  Ship Date Customer ID  \
# 0         1  CA-2016-152156  2016-11-08 2016-11-11    CG-12520
# 1         2  CA-2016-152156  2016-11-08 2016-11-11    CG-12520
# 2         3  CA-2016-138688  2016-06-12 2016-06-16    DV-13045
# 3         4  US-2015-108966  2015-10-11 2015-10-18    SO-20335
# 4         5  US-2015-108966  2015-10-11 2015-10-18    SO-20335
# ..      ...             ...         ...        ...         ...
# 495     496  CA-2015-134782  2015-12-27 2015-12-31    MD-17350
# 496     497  CA-2016-126158  2016-07-25 2016-07-31    SC-20095
# 497     498  CA-2016-126158  2016-07-25 2016-07-31    SC-20095
# 498     499  CA-2016-126158  2016-07-25 2016-07-31    SC-20095
# 499     500  CA-2016-126158  2016-07-25 2016-07-31    SC-20095
#
#           Product ID     Sales ordermonth
# 0    FUR-BO-10001798  261.9600         11
# 1    FUR-CH-10000454  731.9400         11
# 2    OFF-LA-10000240   14.6200         06
# ...

# %%
#create a column ship time to find the processing time in days (ordering date- shipping date)

# %%
newwork["ship_time"]=newwork["Ship Date"]-newwork["Order Date"]

# %%
pd.to_datetime(newwork["Order Date"])
# Out:
# 0     2016-11-08
# 1     2016-11-08
# 2     2016-06-12
# 3     2015-10-11
# 4     2015-10-11
#          ...
# 495   2015-12-27
# 496   2016-07-25
# 497   2016-07-25
# 498   2016-07-25
# 499   2016-07-25
# Name: Order Date, Length: 500, dtype: datetime64[ns]

# %%
newwork["Order Date"]=pd.to_datetime(newwork["Order Date"])

# %%
newwork.dtypes
# Out:
# Row ID                  int64
# Order ID               object
# Order Date     datetime64[ns]
# Ship Date      datetime64[ns]
# Customer ID            object
# Product ID             object
# Sales                 float64
# ordermonth             object
# dtype: object

# %%
newwork
# Out:
#      Row ID        Order ID Order Date  Ship Date Customer ID  \
# 0         1  CA-2016-152156 2016-11-08 2016-11-11    CG-12520
# 1         2  CA-2016-152156 2016-11-08 2016-11-11    CG-12520
# 2         3  CA-2016-138688 2016-06-12 2016-06-16    DV-13045
# 3         4  US-2015-108966 2015-10-11 2015-10-18    SO-20335
# 4         5  US-2015-108966 2015-10-11 2015-10-18    SO-20335
# ..      ...             ...        ...        ...         ...
# 495     496  CA-2015-134782 2015-12-27 2015-12-31    MD-17350
# 496     497  CA-2016-126158 2016-07-25 2016-07-31    SC-20095
# 497     498  CA-2016-126158 2016-07-25 2016-07-31    SC-20095
# 498     499  CA-2016-126158 2016-07-25 2016-07-31    SC-20095
# 499     500  CA-2016-126158 2016-07-25 2016-07-31    SC-20095
#
#           Product ID     Sales ordermonth ship_time
# 0    FUR-BO-10001798  261.9600         11    3 days
# 1    FUR-CH-10000454  731.9400         11    3 days
# 2    OFF-LA-10000240   14.6200         06    4 days
# ...

# %%
newwork.dtypes
# Out:
# Row ID                  int64
# Order ID               object
# Order Date     datetime64[ns]
# Ship Date      datetime64[ns]
# Customer ID            object
# Product ID             object
# Sales                 float64
# ordermonth             object
# dtype: object

# %%
#count the number of orders for each month
newwork["Product ID"].value_counts()
# Out:
# OFF-PA-10001970    4
# TEC-PH-10004093    3
# FUR-BO-10002545    3
# TEC-AC-10004659    3
# FUR-CH-10004063    3
#                   ..
# OFF-ST-10003208    1
# OFF-AP-10001492    1
# OFF-BI-10001922    1
# OFF-LA-10004689    1
# TEC-PH-10000149    1
# Name: Product ID, Length: 442, dtype: int64

# %%
#Count the number of orders in each Month and try to identify seasonality (Pattern) in your data
newwork.groupby("ordermonth").count().reset_index()
#using .count()
# Out:
#    ordermonth  Row ID  Order ID  Order Date  Ship Date  Customer ID  \
# 0          01      13        13          13         13           13
# 1          02       7         7           7          7            7
# 2          03      15        15          15         15           15
# 3          04      52        52          52         52           52
# 4          05      11        11          11         11           11
# 5          06      63        63          63         63           63
# 6          07      25        25          25         25           25
# 7          08      28        28          28         28           28
# 8          09      82        82          82         82           82
# 9          10      51        51          51         51           51
# 10         11      68        68          68         68           68
# 11         12      85        85          85         85           85
#
#     Product ID  Sales  ship_time
# 0           13     13         13
# ...

# %% [markdown]
# # this groups the particular columns you want to be displayed instead of displaying all numerical columns

# %%
newwork.groupby(["ordermonth"])["ship_time"].count().reset_index()
# Out:
#    ordermonth  ship_time
# 0          01         13
# 1          02          7
# 2          03         15
# 3          04         52
# 4          05         11
# 5          06         63
# 6          07         25
# 7          08         28
# 8          09         82
# 9          10         51
# 10         11         68
# 11         12         85

# %% [markdown]
# # .mean() is used to display the average

# %%
newwork["ship_time"].mean(axis=0)
# Out:
# Timedelta('4 days 02:06:43.200000')
