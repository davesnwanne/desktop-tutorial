# %%
import pandas as pd

# %%
pd.read_excel("2017 Order Data.xlsx")
outlets=pd.read_excel("2017 Order Data.xlsx")

# %%
outlets
# Out:
#     Order ID                             Customer ID Cookies Shipped  Revenue  \
# 0     413383                 152689 - YT Restaurants             936   4680.0
# 1     751142  985245 - Quick Bite Convenience Stores             987   4935.0
# 2     876056  985245 - Quick Bite Convenience Stores             270   1350.0
# 3     548247  985245 - Quick Bite Convenience Stores             925   4625.0
# 4     626350                 152689 - YT Restaurants             974   4870.0
# ..       ...                                     ...             ...      ...
# 817   800525                 785432 - Park & Eat LLC             164    820.0
# 818   311436  985245 - Quick Bite Convenience Stores             107    535.0
# 819   XXXXXX                          XXXXXX - Promo             904   4520.0
# 820   617865            452584 - Acme Grocery Stores              62    310.0
# 821   154036                325698 - Cascade Grovers             765   3825.0
#
# ...

# %%
outlets.dtypes
# Out:
# Order ID                   object
# Customer ID                object
# Cookies Shipped            object
# Revenue                   float64
# Cost                       object
# Order Date         datetime64[ns]
# Ship Date          datetime64[ns]
# Order Status               object
# Order Adress               object
# dtype: object

# %%
outlets.columns
# Out:
# Index(['Order ID', 'Customer ID', 'Cookies Shipped', 'Revenue', 'Cost',
#        'Order Date', 'Ship Date', 'Order Status', 'Order Adress'],
#       dtype='object')

# %%
outlets["Customer ID"].str.split("-",expand=True)
# this is to split some
# Out:
#            0                               1
# 0    152689                   YT Restaurants
# 1    985245    Quick Bite Convenience Stores
# 2    985245    Quick Bite Convenience Stores
# 3    985245    Quick Bite Convenience Stores
# 4    152689                   YT Restaurants
# ..       ...                             ...
# 817  785432                   Park & Eat LLC
# 818  985245    Quick Bite Convenience Stores
# 819  XXXXXX                            Promo
# 820  452584              Acme Grocery Stores
# 821  325698                  Cascade Grovers
#
# [822 rows x 2 columns]

# %% [markdown]
# # to create a column and put it in a particular position use the .insert()
# # .insert("number to be put in", "name of the column")

# %%
#create a new column resturant and position in column 2
outlets.insert(2,"resturant name"," ")

# %%
custid=outlets["Customer ID"].str.split("-",expand=True)

# %%
outlets
# Out:
#     Order ID                             Customer ID resturant name  \
# 0     413383                 152689 - YT Restaurants
# 1     751142  985245 - Quick Bite Convenience Stores
# 2     876056  985245 - Quick Bite Convenience Stores
# 3     548247  985245 - Quick Bite Convenience Stores
# 4     626350                 152689 - YT Restaurants
# ..       ...                                     ...            ...
# 817   800525                 785432 - Park & Eat LLC
# 818   311436  985245 - Quick Bite Convenience Stores
# 819   XXXXXX                          XXXXXX - Promo
# 820   617865            452584 - Acme Grocery Stores
# 821   154036                325698 - Cascade Grovers
#
#     Cookies Shipped  Revenue    Cost Order Date  Ship Date Order Status  \
# 0               936   4680.0    2340 2017-12-31 2018-01-05      Shipped
# 1               987   4935.0  2467.5 2017-12-31 2018-01-04      Shipped
# 2               270   1350.0     675 2017-12-30 2018-01-03      Shipped
# ...

# %%
# assign customer id to a variable
custid
# Out:
#            0                               1
# 0    152689                   YT Restaurants
# 1    985245    Quick Bite Convenience Stores
# 2    985245    Quick Bite Convenience Stores
# 3    985245    Quick Bite Convenience Stores
# 4    152689                   YT Restaurants
# ..       ...                             ...
# 817  785432                   Park & Eat LLC
# 818  985245    Quick Bite Convenience Stores
# 819  XXXXXX                            Promo
# 820  452584              Acme Grocery Stores
# 821  325698                  Cascade Grovers
#
# [822 rows x 2 columns]

# %%
outlets["resturant name"]=custid[1]

# %%
outlets
# Out:
#     Order ID                             Customer ID  \
# 0     413383                 152689 - YT Restaurants
# 1     751142  985245 - Quick Bite Convenience Stores
# 2     876056  985245 - Quick Bite Convenience Stores
# 3     548247  985245 - Quick Bite Convenience Stores
# 4     626350                 152689 - YT Restaurants
# ..       ...                                     ...
# 817   800525                 785432 - Park & Eat LLC
# 818   311436  985245 - Quick Bite Convenience Stores
# 819   XXXXXX                          XXXXXX - Promo
# 820   617865            452584 - Acme Grocery Stores
# 821   154036                325698 - Cascade Grovers
#
#                      resturant name Cookies Shipped  Revenue    Cost  \
# 0                    YT Restaurants             936   4680.0    2340
# 1     Quick Bite Convenience Stores             987   4935.0  2467.5
# 2     Quick Bite Convenience Stores             270   1350.0     675
# ...

# %%
outlets["Customer ID"]=custid[0]

# %%
outlets
# Out:
#     Order ID Customer ID                  resturant name Cookies Shipped  \
# 0     413383     152689                   YT Restaurants             936
# 1     751142     985245    Quick Bite Convenience Stores             987
# 2     876056     985245    Quick Bite Convenience Stores             270
# 3     548247     985245    Quick Bite Convenience Stores             925
# 4     626350     152689                   YT Restaurants             974
# ..       ...         ...                             ...             ...
# 817   800525     785432                   Park & Eat LLC             164
# 818   311436     985245    Quick Bite Convenience Stores             107
# 819   XXXXXX     XXXXXX                            Promo             904
# 820   617865     452584              Acme Grocery Stores              62
# 821   154036     325698                  Cascade Grovers             765
#
#      Revenue    Cost Order Date  Ship Date Order Status  \
# ...

# %%
outlets.insert(6,"profit","")
